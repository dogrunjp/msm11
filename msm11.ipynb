# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
from sklearn import datasets
from sklearn import decomposition

# %%
 plt.style.use('seaborn-darkgrid')

# %%
plt.style.available
# Out:
# ['fivethirtyeight',
#  'dark_background',
#  'seaborn-notebook',
#  'seaborn-colorblind',
#  'seaborn-poster',
#  'seaborn-dark-palette',
#  'seaborn-ticks',
#  'seaborn-bright',
#  'seaborn-talk',
#  'seaborn-deep',
#  'ggplot',
#  'seaborn-white',
#  'grayscale',
#  'classic',
#  'bmh',
#  'seaborn-pastel',
#  'seaborn-whitegrid',
#  'seaborn-dark',
#  'seaborn-paper',
#  'seaborn-darkgrid',
#  'seaborn-muted']

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target
target_names = iris.target_names

pca = decomposition.PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# %%
print('xplained variance tatio (first two components): %s'
       % str(pca.explained_variance_ratio_))

colors = ['navy' ,'turquoise', 'darkorange']

for color, i, target_name in zip(colors, [0,1,2], target_names):
    plt.scatter(X_r[y==i, 0], X_r[y==i,1], color=color, alpha=.8,
               label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of IRIS dataset')

plt.plot()
# Out:
# xplained variance tatio (first two components): [ 0.92461621  0.05301557]
# []

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=2)
X_r2 = lda.fit(X, y).transform(X)

# %%
for color, i, target_name in zip(colors, [0,1,2], target_names):
    plt.scatter(X_r2[y==i, 0], X_r2[y == i, 1], alpha=.8, color=color, 
               label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of IRIS dataset')

plt.plot()
# Out:
# []

# %%
kpca = decomposition.KernelPCA(kernel="rbf", n_components=2, fit_inverse_transform=True)
X_kpca = kpca.fit_transform(X)
X_r3 = kpca.inverse_transform(X_kpca)

# %%
print('explained variance ratio (first two components): %s'
    % str(pca.explained_variance_ratio_))
    
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(20,6))

colors = ['navy', 'turquoise', 'darkorange']

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax1.scatter(X_r[y==i, 0], X_r[y==i, 1], color=color, alpha=.8,
               label = target_name)
ax1.legend(loc='best', shadow=False, scatterpoints=1)
ax1.set_title('PCA of IRIS dataset')

ax1.plot()

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax2.scatter(X_r2[y == i, 0], X_r2[y == i, 1], alpha=.8, color=color,
                label=target_name)

ax2.legend(loc='best', shadow=False, scatterpoints=1)
ax2.set_title('LDA of IRIS dataset')

ax2.plot()
# Out:
# explained variance ratio (first two components): [ 0.92461621  0.05301557]
# []
